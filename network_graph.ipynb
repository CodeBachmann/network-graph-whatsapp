# %%
import sys
import os
import pandas as pd
import nltk
import seaborn as sns
import matplotlib
from pathlib import Path

# Usando o TkAGG para interagir com o gráfico
# Se quiser só plotar os gráficos normalmente comente a linha abaixo
matplotlib.use('TkAgg')

import matplotlib.pyplot as plt
import spacy
import re
from nltk.stem import RSLPStemmer
import networkx as nx
from collections import defaultdict
from pyvis.network import Network
import numpy as np

nlp = spacy.load("pt_core_news_sm")
stemmer = RSLPStemmer()

# importando modulo customizado
print(os.getcwd())
# Coloque o seu path
sys.path.append(r'C:\Users\User\Documents\dumps\network-graph-whatsapp')  # Usando o diretório de trabalho atual

import Funcao
# Out:
# C:\Windows\system32

# %% [markdown]
# ### Conectando ao banco e recuperando dados da tabela "hi_conversas"

# %%
import Banco
banco = Banco.CRUD()
resp = banco.fazer_requisicao('SELECT * FROM hi_conversas')
df = pd.DataFrame(resp)

# %% [markdown]
# ### Mapeando as colunas recuperadas para nomes mais descritivos

# %%
mapa = {
    0: 'protocolo_index',
    1: 'protocolo',
    2: 'tipo_remetente',
    3: 'nome_remetente',
    4: 'demora',
    5: 'text',
    6: 'duracao',
    7: 'data',
    8: 'topico',
    9: 'score_score',
    10: 'text_eng',
    11: 'sentiment'
}

df = df.rename(columns=mapa)  # Renomeia as colunas de acordo com o mapa

# %% [markdown]
# ### Limpeza e filtragem dos textos

# %%
# Mantendo apenas as colunas relevantes para análise
df = df[['protocolo', 'protocolo_index', 'text', 'tipo_remetente']]

df = df[df['tipo_remetente'] == 0].copy()


# Filtra as mensagens para remover aquelas cujo protocolo_index termina com "-00"
df = df[~df['protocolo_index'].str.endswith('-00')]

# Aplica a função de formatação e ordena o DataFrame pelo protocolo_index
df['protocolo_index'] = df['protocolo_index'].apply(Funcao.format_index)
df = df.sort_values(by='protocolo_index')
df = df.dropna(subset=['text'])

# Agrupa por protocolo e tipo_remetente, concatenando os textos em uma única string para cada grupo
df = df.groupby(['protocolo', 'tipo_remetente']).agg({
    'text': ' '.join
}).reset_index()

# Remove linhas com texto vazio ou NaN
df['text'] = df.text.apply(lambda x: Funcao.preprocess_text(x))
df['text'] = df.text.apply(lambda x: Funcao.remover_stopwords(x))
df = df[df['text'].str.strip().astype(bool)]  # Filtra textos não vazios

# %% [markdown]
# ### Criação de dicionario para normalizar as palavras

# %%
def lemmatize_text(text):
    doc = nlp(text)
    return ' '.join(token.lemma_ for token in doc)

def stemmer_text(text):
    return ' '.join(stemmer.stem(word) for word in text.split())

# %%
# Dividir o texto em listas de palavras
mapa = {
    0: 'palavra'
}

df['text_split'] = df['text'].apply(lambda x: x.split())


# Explodir a coluna para criar uma linha para cada palavra
df_exploded = df.explode('text_split').groupby("text_split").size().reset_index(name='repeteco').sort_values('repeteco',ascending=False)
df_exploded_grouped_filtered = df_exploded[df_exploded['repeteco'] >= 2]
df_exploded_grouped_filtered = df_exploded_grouped_filtered[~df_exploded_grouped_filtered['text_split'].str.contains(r'\d', regex=True)]
df_palavras = df_exploded_grouped_filtered
df_palavras = df_palavras.drop(columns='repeteco') 
df_palavras
# Out:
#        text_split
# 44686      pedido
# 38152    gostaria
# 31492      compra
# 48537       saber
# 49363        site
# ...           ...
# 51586   vantajoso
# 31589      comrpa
# 27366  amarrotada
# 26816     agendas
# 51167     tulipas
#
# [12987 rows x 1 columns]

# %%
# Função para lematizar tokens em uma string


df_compara = df_palavras
df_compara['text_base'] = df_compara["text_split"].apply(lemmatize_text)
df_compara['text_base'] = df_compara['text_base'].apply(lambda x: x.lower())
df_compara["text_base"] = df_compara['text_base'].apply(stemmer_text)

df_grouped = df_compara.groupby('text_base', as_index=False).agg({
    'text_split': 'first'  
})

mapa = {
    "text_split" : "final_correction"
}
df_grouped = df_grouped.rename(columns=mapa)
merged_df = pd.merge(df_compara, df_grouped[['text_base', 'final_correction']], on='text_base', how='left')
final_compare_df = merged_df
final_compare_df
# Out:
#        text_split text_base final_correction
# 0          pedido       ped           pedido
# 1        gostaria      gost         gostaria
# 2          compra     compr           compra
# 3           saber       sab            saber
# 4            site       sit             site
# ...           ...       ...              ...
# 12982   vantajoso    vantaj        vantajoso
# 12983      comrpa     comrp           comrpa
# 12984  amarrotada   amarrot         amarrota
# 12985     agendas     agenr          agendas
# 12986     tulipas     tulip          tulipas
#
# [12987 rows x 3 columns]

# %%
dic_compare = final_compare_df.to_dict()
keys = dic_compare['text_base'].keys()
for k in keys:
    dic = {

        'text_split' : dic_compare['text_split'][k],
        'text_base' : dic_compare['text_base'][k],
        'final_correction':dic_compare['final_correction'][k]
    }
    query = Funcao.montar_query_insert(dic,'dicionario_simplificante','n')
    banco.fazer_requisicao(query)
# Out:
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pedido', 'ped', 'pedido');
# MySQL Error: (1062, "Duplicate entry 'pedido' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('gostaria', 'gost', 'gostaria');
# MySQL Error: (1062, "Duplicate entry 'gostaria' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('compra', 'compr', 'compra');
# MySQL Error: (1062, "Duplicate entry 'compra' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('saber', 'sab', 'saber');
# MySQL Error: (1062, "Duplicate entry 'saber' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('site', 'sit', 'site');
# MySQL Error: (1062, "Duplicate entry 'site' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('mail', 'mail', 'mail');
# MySQL Error: (1062, "Duplicate entry 'mail' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('fazer', 'faz', 'fazer');
# MySQL Error: (1062, "Duplicate entry 'fazer' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('camisetas', 'camiset', 'camisetas');
# MySQL Error: (1062, "Duplicate entry 'camisetas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pra', 'pra', 'pra');
# MySQL Error: (1062, "Duplicate entry 'pra' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('entrega', 'entreg', 'entrega');
# MySQL Error: (1062, "Duplicate entry 'entrega' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('quero', 'quer', 'quero');
# MySQL Error: (1062, "Duplicate entry 'quero' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('preciso', 'precis', 'preciso');
# MySQL Error: (1062, "Duplicate entry 'preciso' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('valor', 'val', 'valor');
# MySQL Error: (1062, "Duplicate entry 'valor' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('recebi', 'receb', 'recebi');
# MySQL Error: (1062, "Duplicate entry 'recebi' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pagamento', 'pag', 'pagamento');
# MySQL Error: (1062, "Duplicate entry 'pagamento' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cpf', 'cpf', 'cpf');
# MySQL Error: (1062, "Duplicate entry 'cpf' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('entao', 'enta', 'entao');
# MySQL Error: (1062, "Duplicate entry 'entao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tamanho', 'tamanh', 'tamanho');
# MySQL Error: (1062, "Duplicate entry 'tamanho' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('comprar', 'compr', 'compra');
# MySQL Error: (1062, "Duplicate entry 'comprar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('camisas', 'camis', 'camisas');
# MySQL Error: (1062, "Duplicate entry 'camisas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pecas', 'pec', 'pecas');
# MySQL Error: (1062, "Duplicate entry 'pecas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('troca', 'troc', 'troca');
# MySQL Error: (1062, "Duplicate entry 'troca' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ta', 'ta', 'ta');
# MySQL Error: (1062, "Duplicate entry 'ta' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('consigo', 'consig', 'consigo');
# MySQL Error: (1062, "Duplicate entry 'consigo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('camiseta', 'camiset', 'camisetas');
# MySQL Error: (1062, "Duplicate entry 'camiseta' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('kit', 'kit', 'kit');
# MySQL Error: (1062, "Duplicate entry 'kit' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('polo', 'pol', 'polo');
# MySQL Error: (1062, "Duplicate entry 'polo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('contato', 'contat', 'contato');
# MySQL Error: (1062, "Duplicate entry 'contato' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cor', 'cor', 'cor');
# MySQL Error: (1062, "Duplicate entry 'cor' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pix', 'pix', 'pix');
# MySQL Error: (1062, "Duplicate entry 'pix' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('endereco', 'enderec', 'endereco');
# MySQL Error: (1062, "Duplicate entry 'endereco' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cupom', 'cupom', 'cupom');
# MySQL Error: (1062, "Duplicate entry 'cupom' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('desconto', 'descont', 'desconto');
# MySQL Error: (1062, "Duplicate entry 'desconto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('somente', 'soment', 'somente');
# MySQL Error: (1062, "Duplicate entry 'somente' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('codigo', 'codig', 'codigo');
# MySQL Error: (1062, "Duplicate entry 'codigo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('camisa', 'camis', 'camisas');
# MySQL Error: (1062, "Duplicate entry 'camisa' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('rastreio', 'rastrei', 'rastreio');
# MySQL Error: (1062, "Duplicate entry 'rastreio' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('algodao', 'algoda', 'algodao');
# MySQL Error: (1062, "Duplicate entry 'algodao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('loja', 'loj', 'loja');
# MySQL Error: (1062, "Duplicate entry 'loja' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('g', 'g', 'g');
# MySQL Error: (1062, "Duplicate entry 'g' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('link', 'linkr', 'link');
# MySQL Error: (1062, "Duplicate entry 'link' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('comprei', 'compr', 'compra');
# MySQL Error: (1062, "Duplicate entry 'comprei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cartao', 'carta', 'cartao');
# MySQL Error: (1062, "Duplicate entry 'cartao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('wholesale', 'wholesal', 'wholesale');
# MySQL Error: (1062, "Duplicate entry 'wholesale' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('dias', 'dia', 'dias');
# MySQL Error: (1062, "Duplicate entry 'dias' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('m', 'm', 'm');
# MySQL Error: (1062, "Duplicate entry 'm' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cores', 'cor', 'cor');
# MySQL Error: (1062, "Duplicate entry 'cores' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('transportadora', 'transport', 'transportadora');
# MySQL Error: (1062, "Duplicate entry 'transportadora' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cadastro', 'cadastr', 'cadastro');
# MySQL Error: (1062, "Duplicate entry 'cadastro' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('enviar', 'envi', 'enviar');
# MySQL Error: (1062, "Duplicate entry 'enviar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('prazo', 'praz', 'prazo');
# MySQL Error: (1062, "Duplicate entry 'prazo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('consegui', 'consegu', 'consegui');
# MySQL Error: (1062, "Duplicate entry 'consegui' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('trocar', 'troc', 'troca');
# MySQL Error: (1062, "Duplicate entry 'trocar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('chegou', 'cheg', 'chegou');
# MySQL Error: (1062, "Duplicate entry 'chegou' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('devolucao', 'devoluca', 'devolucao');
# MySQL Error: (1062, "Duplicate entry 'devolucao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('gg', 'gg', 'gg');
# MySQL Error: (1062, "Duplicate entry 'gg' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('email', 'email', 'email');
# MySQL Error: (1062, "Duplicate entry 'email' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agradeco', 'agradec', 'agradeco');
# MySQL Error: (1062, "Duplicate entry 'agradeco' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('aguardando', 'aguard', 'aguardando');
# MySQL Error: (1062, "Duplicate entry 'aguardando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('senha', 'senh', 'senha');
# MySQL Error: (1062, "Duplicate entry 'senha' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('produto', 'produt', 'produto');
# MySQL Error: (1062, "Duplicate entry 'produto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('p', 'p', 'p');
# MySQL Error: (1062, "Duplicate entry 'p' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('mensagem', 'mens', 'mensagem');
# MySQL Error: (1062, "Duplicate entry 'mensagem' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('vi', 'ver', 'vi');
# MySQL Error: (1062, "Duplicate entry 'vi' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('atendimento', 'atend', 'atendimento');
# MySQL Error: (1062, "Duplicate entry 'atendimento' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('novamente', 'nov', 'novamente');
# MySQL Error: (1062, "Duplicate entry 'novamente' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ah', 'ah', 'ah');
# MySQL Error: (1062, "Duplicate entry 'ah' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('retorno', 'retorn', 'retorno');
# MySQL Error: (1062, "Duplicate entry 'retorno' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('azul', 'azul', 'azul');
# MySQL Error: (1062, "Duplicate entry 'azul' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('entregue', 'entreg', 'entrega');
# MySQL Error: (1062, "Duplicate entry 'entregue' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('orcamento', 'orc', 'orcamento');
# MySQL Error: (1062, "Duplicate entry 'orcamento' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('frete', 'fret', 'frete');
# MySQL Error: (1062, "Duplicate entry 'frete' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('caso', 'cas', 'caso');
# MySQL Error: (1062, "Duplicate entry 'caso' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('verificar', 'verific', 'verificar');
# MySQL Error: (1062, "Duplicate entry 'verificar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('malha', 'malh', 'malha');
# MySQL Error: (1062, "Duplicate entry 'malha' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('mim', 'eu', 'mim');
# MySQL Error: (1062, "Duplicate entry 'mim' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('empresa', 'empr', 'empresa');
# MySQL Error: (1062, "Duplicate entry 'empresa' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('preco', 'prec', 'preco');
# MySQL Error: (1062, "Duplicate entry 'preco' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tempo', 'temp', 'tempo');
# MySQL Error: (1062, "Duplicate entry 'tempo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('otimo', 'otim', 'otimo');
# MySQL Error: (1062, "Duplicate entry 'otimo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('problema', 'problem', 'problema');
# MySQL Error: (1062, "Duplicate entry 'problema' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('atencao', 'atenca', 'atencao');
# MySQL Error: (1062, "Duplicate entry 'atencao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('previsao', 'previsa', 'previsao');
# MySQL Error: (1062, "Duplicate entry 'previsao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('chegar', 'cheg', 'chegou');
# MySQL Error: (1062, "Duplicate entry 'chegar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('errado', 'err', 'errado');
# MySQL Error: (1062, "Duplicate entry 'errado' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('informacoes', 'informaco', 'informacoes');
# MySQL Error: (1062, "Duplicate entry 'informacoes' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('valores', 'val', 'valor');
# MySQL Error: (1062, "Duplicate entry 'valores' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('n', 'n', 'n');
# MySQL Error: (1062, "Duplicate entry 'n' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('preta', 'pret', 'preta');
# MySQL Error: (1062, "Duplicate entry 'preta' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pagar', 'pag', 'pagamento');
# MySQL Error: (1062, "Duplicate entry 'pagar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('rastrear', 'rastr', 'rastrear');
# MySQL Error: (1062, "Duplicate entry 'rastrear' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cancelar', 'cancel', 'cancelar');
# MySQL Error: (1062, "Duplicate entry 'cancelar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('entrar', 'entr', 'entrar');
# MySQL Error: (1062, "Duplicate entry 'entrar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('receber', 'receb', 'recebi');
# MySQL Error: (1062, "Duplicate entry 'receber' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('falar', 'fal', 'falar');
# MySQL Error: (1062, "Duplicate entry 'falar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('fica', 'fic', 'fica');
# MySQL Error: (1062, "Duplicate entry 'fica' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tamanhos', 'tamanh', 'tamanho');
# MySQL Error: (1062, "Duplicate entry 'tamanhos' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('consegue', 'consegu', 'consegui');
# MySQL Error: (1062, "Duplicate entry 'consegue' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('conseguindo', 'consegu', 'consegui');
# MySQL Error: (1062, "Duplicate entry 'conseguindo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('mandar', 'mand', 'mandar');
# MySQL Error: (1062, "Duplicate entry 'mandar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cnpj', 'cnpj', 'cnpj');
# MySQL Error: (1062, "Duplicate entry 'cnpj' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('feminina', 'feminin', 'feminina');
# MySQL Error: (1062, "Duplicate entry 'feminina' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('dry', 'dry', 'dry');
# MySQL Error: (1062, "Duplicate entry 'dry' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('acima', 'acim', 'acima');
# MySQL Error: (1062, "Duplicate entry 'acima' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('boleto', 'bolet', 'boleto');
# MySQL Error: (1062, "Duplicate entry 'boleto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('masculina', 'masculin', 'masculina');
# MySQL Error: (1062, "Duplicate entry 'masculina' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('gentileza', 'gentil', 'gentileza');
# MySQL Error: (1062, "Duplicate entry 'gentileza' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('quantidade', 'quant', 'quantidade');
# MySQL Error: (1062, "Duplicate entry 'quantidade' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tentar', 'tent', 'tentar');
# MySQL Error: (1062, "Duplicate entry 'tentar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('correto', 'corret', 'correto');
# MySQL Error: (1062, "Duplicate entry 'correto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('branca', 'branc', 'branca');
# MySQL Error: (1062, "Duplicate entry 'branca' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('produtos', 'produt', 'produto');
# MySQL Error: (1062, "Duplicate entry 'produtos' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('aparece', 'aparec', 'aparece');
# MySQL Error: (1062, "Duplicate entry 'aparece' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('semana', 'seman', 'semana');
# MySQL Error: (1062, "Duplicate entry 'semana' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('casa', 'cas', 'caso');
# MySQL Error: (1062, "Duplicate entry 'casa' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('fit', 'fit', 'fit');
# MySQL Error: (1062, "Duplicate entry 'fit' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tentei', 'tent', 'tentar');
# MySQL Error: (1062, "Duplicate entry 'tentei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('perfeito', 'perfeit', 'perfeito');
# MySQL Error: (1062, "Duplicate entry 'perfeito' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cep', 'cep', 'cep');
# MySQL Error: (1062, "Duplicate entry 'cep' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('finalizar', 'final', 'finalizar');
# MySQL Error: (1062, "Duplicate entry 'finalizar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('opcao', 'opca', 'opcao');
# MySQL Error: (1062, "Duplicate entry 'opcao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cinza', 'cinz', 'cinza');
# MySQL Error: (1062, "Duplicate entry 'cinza' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('reembolso', 'reembols', 'reembolso');
# MySQL Error: (1062, "Duplicate entry 'reembolso' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('encomenda', 'encomend', 'encomenda');
# MySQL Error: (1062, "Duplicate entry 'encomenda' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('veio', 'vir', 'veio');
# MySQL Error: (1062, "Duplicate entry 'veio' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('envio', 'envi', 'enviar');
# MySQL Error: (1062, "Duplicate entry 'envio' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tecido', 'tec', 'tecido');
# MySQL Error: (1062, "Duplicate entry 'tecido' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('acho', 'ach', 'acho');
# MySQL Error: (1062, "Duplicate entry 'acho' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('passar', 'pass', 'passar');
# MySQL Error: (1062, "Duplicate entry 'passar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('paguei', 'pag', 'pagamento');
# MySQL Error: (1062, "Duplicate entry 'paguei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ne', 'ne', 'ne');
# MySQL Error: (1062, "Duplicate entry 'ne' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('beleza', 'bel', 'beleza');
# MySQL Error: (1062, "Duplicate entry 'beleza' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('resolver', 'resolv', 'resolver');
# MySQL Error: (1062, "Duplicate entry 'resolver' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('marinho', 'mar', 'marinho');
# MySQL Error: (1062, "Duplicate entry 'marinho' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('realizar', 'realiz', 'realizar');
# MySQL Error: (1062, "Duplicate entry 'realizar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('manga', 'mang', 'manga');
# MySQL Error: (1062, "Duplicate entry 'manga' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('mirante', 'mir', 'mirante');
# MySQL Error: (1062, "Duplicate entry 'mirante' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('erro', 'err', 'errado');
# MySQL Error: (1062, "Duplicate entry 'erro' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ajudar', 'ajud', 'ajudar');
# MySQL Error: (1062, "Duplicate entry 'ajudar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('uniforme', 'uniform', 'uniforme');
# MySQL Error: (1062, "Duplicate entry 'uniforme' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('polos', 'pol', 'polo');
# MySQL Error: (1062, "Duplicate entry 'polos' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('conta', 'cont', 'conta');
# MySQL Error: (1062, "Duplicate entry 'conta' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('gola', 'gol', 'gola');
# MySQL Error: (1062, "Duplicate entry 'gola' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('verde', 'verd', 'verde');
# MySQL Error: (1062, "Duplicate entry 'verde' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('carrinho', 'carr', 'carrinho');
# MySQL Error: (1062, "Duplicate entry 'carrinho' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('rua', 'rua', 'rua');
# MySQL Error: (1062, "Duplicate entry 'rua' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('opcoes', 'opco', 'opcoes');
# MySQL Error: (1062, "Duplicate entry 'opcoes' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('moletom', 'moletom', 'moletom');
# MySQL Error: (1062, "Duplicate entry 'moletom' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tentando', 'tent', 'tentar');
# MySQL Error: (1062, "Duplicate entry 'tentando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('acabei', 'acab', 'acabei');
# MySQL Error: (1062, "Duplicate entry 'acabei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('informacao', 'informaca', 'informacao');
# MySQL Error: (1062, "Duplicate entry 'informacao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('peca', 'pec', 'pecas');
# MySQL Error: (1062, "Duplicate entry 'peca' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('unidades', 'unidad', 'unidades');
# MySQL Error: (1062, "Duplicate entry 'unidades' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('consta', 'const', 'consta');
# MySQL Error: (1062, "Duplicate entry 'consta' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('estorno', 'estorn', 'estorno');
# MySQL Error: (1062, "Duplicate entry 'estorno' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('blusas', 'blus', 'blusas');
# MySQL Error: (1062, "Duplicate entry 'blusas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('colocar', 'coloc', 'colocar');
# MySQL Error: (1062, "Duplicate entry 'colocar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('alterar', 'alter', 'alterar');
# MySQL Error: (1062, "Duplicate entry 'alterar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('modelo', 'model', 'modelo');
# MySQL Error: (1062, "Duplicate entry 'modelo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('melhor', 'bom', 'melhor');
# MySQL Error: (1062, "Duplicate entry 'melhor' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('achei', 'ach', 'acho');
# MySQL Error: (1062, "Duplicate entry 'achei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('entregar', 'entreg', 'entrega');
# MySQL Error: (1062, "Duplicate entry 'entregar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cliente', 'client', 'cliente');
# MySQL Error: (1062, "Duplicate entry 'cliente' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('fria', 'fri', 'fria');
# MySQL Error: (1062, "Duplicate entry 'fria' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pedidos', 'ped', 'pedido');
# MySQL Error: (1062, "Duplicate entry 'pedidos' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('coloquei', 'coloq', 'coloquei');
# MySQL Error: (1062, "Duplicate entry 'coloquei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('recusado', 'recus', 'recusado');
# MySQL Error: (1062, "Duplicate entry 'recusado' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('r', 'r', 'r');
# MySQL Error: (1062, "Duplicate entry 'r' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ficou', 'fic', 'fica');
# MySQL Error: (1062, "Duplicate entry 'ficou' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('compras', 'compr', 'compra');
# MySQL Error: (1062, "Duplicate entry 'compras' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('confirmar', 'confirm', 'confirmar');
# MySQL Error: (1062, "Duplicate entry 'confirmar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('informar', 'inform', 'informar');
# MySQL Error: (1062, "Duplicate entry 'informar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pedir', 'ped', 'pedido');
# MySQL Error: (1062, "Duplicate entry 'pedir' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('funciona', 'funcion', 'funciona');
# MySQL Error: (1062, "Duplicate entry 'funciona' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pedi', 'ped', 'pedido');
# MySQL Error: (1062, "Duplicate entry 'pedi' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('chega', 'cheg', 'chegou');
# MySQL Error: (1062, "Duplicate entry 'chega' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('nota', 'not', 'nota');
# MySQL Error: (1062, "Duplicate entry 'nota' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('poliester', 'poliest', 'poliester');
# MySQL Error: (1062, "Duplicate entry 'poliester' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pendente', 'pend', 'pendente');
# MySQL Error: (1062, "Duplicate entry 'pendente' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('data', 'dat', 'data');
# MySQL Error: (1062, "Duplicate entry 'data' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pago', 'pag', 'pagamento');
# MySQL Error: (1062, "Duplicate entry 'pago' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('to', 'to', 'to');
# MySQL Error: (1062, "Duplicate entry 'to' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('catalogo', 'catalog', 'catalogo');
# MySQL Error: (1062, "Duplicate entry 'catalogo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('medidas', 'med', 'medidas');
# MySQL Error: (1062, "Duplicate entry 'medidas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('xgg', 'xgg', 'xgg');
# MySQL Error: (1062, "Duplicate entry 'xgg' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('amanha', 'amanh', 'amanha');
# MySQL Error: (1062, "Duplicate entry 'amanha' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('credito', 'credit', 'credito');
# MySQL Error: (1062, "Duplicate entry 'credito' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('disponiveis', 'disponi', 'disponiveis');
# MySQL Error: (1062, "Duplicate entry 'disponiveis' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('foto', 'fot', 'foto');
# MySQL Error: (1062, "Duplicate entry 'foto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('enviado', 'envi', 'enviar');
# MySQL Error: (1062, "Duplicate entry 'enviado' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('efetuar', 'efetu', 'efetuar');
# MySQL Error: (1062, "Duplicate entry 'efetuar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('feira', 'feir', 'feira');
# MySQL Error: (1062, "Duplicate entry 'feira' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('via', 'ver', 'vi');
# MySQL Error: (1062, "Duplicate entry 'via' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('diferenca', 'diferenc', 'diferenca');
# MySQL Error: (1062, "Duplicate entry 'diferenca' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('look', 'look', 'look');
# MySQL Error: (1062, "Duplicate entry 'look' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('comprovante', 'comprov', 'comprovante');
# MySQL Error: (1062, "Duplicate entry 'comprovante' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('entrei', 'entr', 'entrar');
# MySQL Error: (1062, "Duplicate entry 'entrei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('acessar', 'acess', 'acessar');
# MySQL Error: (1062, "Duplicate entry 'acessar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('resposta', 'respost', 'resposta');
# MySQL Error: (1062, "Duplicate entry 'resposta' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('baby', 'baby', 'baby');
# MySQL Error: (1062, "Duplicate entry 'baby' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('trabalham', 'trabalh', 'trabalham');
# MySQL Error: (1062, "Duplicate entry 'trabalham' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('realizei', 'realize', 'realizei');
# MySQL Error: (1062, "Duplicate entry 'realizei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('demora', 'dem', 'demora');
# MySQL Error: (1062, "Duplicate entry 'demora' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('mercadoria', 'mercad', 'mercadoria');
# MySQL Error: (1062, "Duplicate entry 'mercadoria' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('lisas', 'lis', 'lisas');
# MySQL Error: (1062, "Duplicate entry 'lisas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('solicitei', 'solic', 'solicitei');
# MySQL Error: (1062, "Duplicate entry 'solicitei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('claro', 'clar', 'claro');
# MySQL Error: (1062, "Duplicate entry 'claro' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ficar', 'fic', 'fica');
# MySQL Error: (1062, "Duplicate entry 'ficar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('devolver', 'devolv', 'devolver');
# MySQL Error: (1062, "Duplicate entry 'devolver' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tipo', 'tip', 'tipo');
# MySQL Error: (1062, "Duplicate entry 'tipo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('uteis', 'ute', 'uteis');
# MySQL Error: (1062, "Duplicate entry 'uteis' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ajuda', 'ajud', 'ajudar');
# MySQL Error: (1062, "Duplicate entry 'ajuda' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('personalizacao', 'personalizaca', 'personalizacao');
# MySQL Error: (1062, "Duplicate entry 'personalizacao' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('horario', 'horari', 'horario');
# MySQL Error: (1062, "Duplicate entry 'horario' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('qualidade', 'qual', 'qualidade');
# MySQL Error: (1062, "Duplicate entry 'qualidade' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('dando', 'dar', 'dando');
# MySQL Error: (1062, "Duplicate entry 'dando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('precisa', 'precis', 'preciso');
# MySQL Error: (1062, "Duplicate entry 'precisa' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('diferentes', 'difer', 'diferentes');
# MySQL Error: (1062, "Duplicate entry 'diferentes' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('rastreamento', 'rastre', 'rastreamento');
# MySQL Error: (1062, "Duplicate entry 'rastreamento' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('blusa', 'blus', 'blusas');
# MySQL Error: (1062, "Duplicate entry 'blusa' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('irei', 'ir', 'irei');
# MySQL Error: (1062, "Duplicate entry 'irei' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('escolher', 'escolh', 'escolher');
# MySQL Error: (1062, "Duplicate entry 'escolher' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('disponivel', 'disponi', 'disponiveis');
# MySQL Error: (1062, "Duplicate entry 'disponivel' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('premium', 'premiumr', 'premium');
# MySQL Error: (1062, "Duplicate entry 'premium' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('minimo', 'min', 'minimo');
# MySQL Error: (1062, "Duplicate entry 'minimo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('dados', 'dad', 'dados');
# MySQL Error: (1062, "Duplicate entry 'dados' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('kits', 'kit', 'kit');
# MySQL Error: (1062, "Duplicate entry 'kits' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('preto', 'pret', 'preta');
# MySQL Error: (1062, "Duplicate entry 'preto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('dryfit', 'dryfit', 'dryfit');
# MySQL Error: (1062, "Duplicate entry 'dryfit' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('basicas', 'basic', 'basicas');
# MySQL Error: (1062, "Duplicate entry 'basicas' for key 'dicionario_simplificante.PRIMARY'")
# ...
# MySQL Error: (1062, "Duplicate entry 'turu' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ceerto', 'ceert', 'ceerto');
# MySQL Error: (1062, "Duplicate entry 'ceerto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('vandervan', 'vandervan', 'vandervan');
# MySQL Error: (1062, "Duplicate entry 'vandervan' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('turistas', 'turist', 'turistas');
# MySQL Error: (1062, "Duplicate entry 'turistas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('vanda', 'vand', 'vanda');
# MySQL Error: (1062, "Duplicate entry 'vanda' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('chateaubriand', 'chateaubriand', 'chateaubriand');
# MySQL Error: (1062, "Duplicate entry 'chateaubriand' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('van', 'van', 'vania');
# MySQL Error: (1062, "Duplicate entry 'van' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('desconte', 'descont', 'desconto');
# MySQL Error: (1062, "Duplicate entry 'desconte' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agonia', 'agoni', 'agonia');
# MySQL Error: (1062, "Duplicate entry 'agonia' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('descontava', 'descont', 'desconto');
# MySQL Error: (1062, "Duplicate entry 'descontava' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('turqueza', 'turqu', 'turquesa');
# MySQL Error: (1062, "Duplicate entry 'turqueza' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('padastro', 'padastr', 'padastro');
# MySQL Error: (1062, "Duplicate entry 'padastro' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ceeto', 'ceet', 'ceeto');
# MySQL Error: (1062, "Duplicate entry 'ceeto' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agota', 'agot', 'agota');
# MySQL Error: (1062, "Duplicate entry 'agota' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('padronizado', 'padron', 'padronizadas');
# MySQL Error: (1062, "Duplicate entry 'padronizado' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('paea', 'pae', 'paea');
# MySQL Error: (1062, "Duplicate entry 'paea' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pagode', 'pagod', 'pagode');
# MySQL Error: (1062, "Duplicate entry 'pagode' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agrado', 'agr', 'agrada');
# MySQL Error: (1062, "Duplicate entry 'agrado' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('persistencia', 'persistenc', 'persistencia');
# MySQL Error: (1062, "Duplicate entry 'persistencia' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('persoa', 'perso', 'persoa');
# MySQL Error: (1062, "Duplicate entry 'persoa' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('desconfiando', 'desconfi', 'desconfiado');
# MySQL Error: (1062, "Duplicate entry 'desconfiando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('paicandu', 'paicandu', 'paicandu');
# MySQL Error: (1062, "Duplicate entry 'paicandu' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('desconfiada', 'desconfi', 'desconfiado');
# MySQL Error: (1062, "Duplicate entry 'desconfiada' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('valoe', 'valo', 'valoe');
# MySQL Error: (1062, "Duplicate entry 'valoe' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('paineiras', 'pain', 'paineiras');
# MySQL Error: (1062, "Duplicate entry 'paineiras' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('amadio', 'amadi', 'amadio');
# MySQL Error: (1062, "Duplicate entry 'amadio' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('comprovo', 'comprov', 'comprovante');
# MySQL Error: (1062, "Duplicate entry 'comprovo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ua', 'ua', 'ua');
# MySQL Error: (1062, "Duplicate entry 'ua' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('amada', 'am', 'amor');
# MySQL Error: (1062, "Duplicate entry 'amada' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('celere', 'celer', 'celere');
# MySQL Error: (1062, "Duplicate entry 'celere' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('comprovente', 'comprov', 'comprovante');
# MySQL Error: (1062, "Duplicate entry 'comprovente' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('aguadando', 'aguad', 'aguadando');
# MySQL Error: (1062, "Duplicate entry 'aguadando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('valir', 'val', 'valor');
# MySQL Error: (1062, "Duplicate entry 'valir' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('desconfortaveis', 'desconforta', 'desconfortavel');
# MySQL Error: (1062, "Duplicate entry 'desconfortaveis' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('cegou', 'ceg', 'cegas');
# MySQL Error: (1062, "Duplicate entry 'cegou' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('descono', 'descon', 'descono');
# MySQL Error: (1062, "Duplicate entry 'descono' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('desconhecida', 'desconhec', 'desconheco');
# MySQL Error: (1062, "Duplicate entry 'desconhecida' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('valos', 'val', 'valor');
# MySQL Error: (1062, "Duplicate entry 'valos' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('desconfortante', 'desconfort', 'desconforto');
# MySQL Error: (1062, "Duplicate entry 'desconfortante' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agricultura', 'agricult', 'agricultura');
# MySQL Error: (1062, "Duplicate entry 'agricultura' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('amadorismo', 'amador', 'amadorismo');
# MySQL Error: (1062, "Duplicate entry 'amadorismo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agdo', 'agd', 'agdo');
# MySQL Error: (1062, "Duplicate entry 'agdo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('vanilce', 'vanilc', 'vanilce');
# MySQL Error: (1062, "Duplicate entry 'vanilce' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('vapores', 'vap', 'vapores');
# MySQL Error: (1062, "Duplicate entry 'vapores' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('personalizaria', 'personal', 'personalizadas');
# MySQL Error: (1062, "Duplicate entry 'personalizaria' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ouco', 'ouc', 'ouco');
# MySQL Error: (1062, "Duplicate entry 'ouco' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('varal', 'varal', 'varal');
# MySQL Error: (1062, "Duplicate entry 'varal' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agilizaria', 'agiliz', 'agilizar');
# MySQL Error: (1062, "Duplicate entry 'agilizaria' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agilizassem', 'agiliz', 'agilizar');
# MySQL Error: (1062, "Duplicate entry 'agilizassem' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('overside', 'oversid', 'overside');
# MySQL Error: (1062, "Duplicate entry 'overside' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('outr', 'outr', 'outr');
# MySQL Error: (1062, "Duplicate entry 'outr' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('overlock', 'overlock', 'overlock');
# MySQL Error: (1062, "Duplicate entry 'overlock' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agendando', 'agend', 'agendar');
# MySQL Error: (1062, "Duplicate entry 'agendando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('delvover', 'delvov', 'delvover');
# MySQL Error: (1062, "Duplicate entry 'delvover' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ovando', 'ov', 'ovada');
# MySQL Error: (1062, "Duplicate entry 'ovando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('personalizariam', 'personalizar', 'personalizariam');
# MySQL Error: (1062, "Duplicate entry 'personalizariam' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agilizando', 'agiliz', 'agilizar');
# MySQL Error: (1062, "Duplicate entry 'agilizando' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ageis', 'agel', 'ageis');
# MySQL Error: (1062, "Duplicate entry 'ageis' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ovos', 'ovo', 'ovo');
# MySQL Error: (1062, "Duplicate entry 'ovos' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agilizado', 'agiliz', 'agilizar');
# MySQL Error: (1062, "Duplicate entry 'agilizado' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('descreve', 'descrev', 'descrito');
# MySQL Error: (1062, "Duplicate entry 'descreve' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('descosturadas', 'descostur', 'descosturada');
# MySQL Error: (1062, "Duplicate entry 'descosturadas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agilizava', 'agiliz', 'agilizar');
# MySQL Error: (1062, "Duplicate entry 'agilizava' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('amarrar', 'amarr', 'amarrar');
# MySQL Error: (1062, "Duplicate entry 'amarrar' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('over', 'ov', 'ovada');
# MySQL Error: (1062, "Duplicate entry 'over' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ouvem', 'ouv', 'ouve');
# MySQL Error: (1062, "Duplicate entry 'ouvem' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('ouvindo', 'ouv', 'ouve');
# MySQL Error: (1062, "Duplicate entry 'ouvindo' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pacaembu', 'pacaembu', 'pacaembu');
# MySQL Error: (1062, "Duplicate entry 'pacaembu' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('overloque', 'overloqu', 'overloque');
# MySQL Error: (1062, "Duplicate entry 'overloque' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('pacembu', 'pacembur', 'pacembu');
# MySQL Error: (1062, "Duplicate entry 'pacembu' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('vantajoso', 'vantaj', 'vantajoso');
# MySQL Error: (1062, "Duplicate entry 'vantajoso' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('comrpa', 'comrp', 'comrpa');
# MySQL Error: (1062, "Duplicate entry 'comrpa' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('amarrotada', 'amarrot', 'amarrota');
# MySQL Error: (1062, "Duplicate entry 'amarrotada' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('agendas', 'agenr', 'agendas');
# MySQL Error: (1062, "Duplicate entry 'agendas' for key 'dicionario_simplificante.PRIMARY'")
# INSERT INTO dicionario_simplificante (text_split, text_base, final_correction) VALUES ('tulipas', 'tulip', 'tulipas');
# MySQL Error: (1062, "Duplicate entry 'tulipas' for key 'dicionario_simplificante.PRIMARY'")

# %% [markdown]
# ### Coletando dicionario de palavras do banco MySQL para ajustar os textos do DataFrame

# %%
resp  = banco.fazer_requisicao("select * from dicionario_simplificante")
df_dicionario = pd.DataFrame(resp)
mapa = {

    0: "text_split",
    1: "text_base",
    2: "final_correction"
}
df_dicionario = df_dicionario.rename(columns=mapa)

# %% [markdown]
# ### Criando Função para ajustar os textos do DataFrame

# %%
def replace_words_in_text(text, replacements):
    # Divida o texto em palavras
    words = text.split()
    # Substitua as palavras com base no DataFrame de substituições
    corrected_words = [replacements.get(word, word) for word in words]
    # Junte as palavras de volta em um texto
    return ' '.join(corrected_words)

replacement_dict = dict(zip(df_dicionario['text_split'], df_dicionario['final_correction']))

# %%
def replace_words(text):
    # Dicionário de substituições dentro da função
    alter_words = {

        ' gostaria ': ' quero ',
        ' nao ': ' nao ',
        ' preciso ': ' quero ',
        ' queria ': ' quero ',
        ' desejo ': ' quero ',
        ' negativo ':' nao ',
        ' camiseta': ' camisa ',
        ' quero ':' quero ',
        ' malha fria ':' malha-fria ',
        ' azul marinho ': ' azul-marinho ',
        ' dry fit ': ' dry-fit ',
        ' s ': ' ',
        ' pretendo ': ' quero ',
        ' almejo ': ' quero ',
        ' necessito ': ' quero ',
        ' n ':' nao ',
        ' cartao credito ': ' cartao-credito ',
        ' manga longa ': ' manga-longa ',
        ' loja mirante ': ' loja-mirante ',
        ' nota fiscal ' : ' nf '
        
    }
    
    # Substituindo palavras de acordo com o dicionário
    for word, replacement in alter_words.items():
        text = text.replace(word, replacement)
    return text

# %% [markdown]
# ### Aplica as funções

# %%
df['text'] = df['text'].apply(lambda x: replace_words_in_text(x, replacement_dict))
df['text'] = df['text'].apply(lambda x: replace_words(x))

# %% [markdown]
# ### Remove palavras que contenham ou sejam compostas por numeros

# %%
def remove_words_with_numbers(text):
    # Regex para remover palavras que contenham números
    return re.sub(r'\b\w*\d\w*\b', '', text).strip()

# Aplicando a função em toda a coluna de textos
df['text'] = df['text'].apply(lambda x: remove_words_with_numbers(x))

# %% [markdown]
# ### Cria a relação entre as palavras de cada texto

# %%
def build_cooccurrence_graph(texts):
    G = nx.Graph()  # Criar um grafo vazio
    for text in texts:
        words = text.split()  # Tokenizar o texto
        for i in range(len(words) - 1):
            word_pair = (words[i], words[i + 1])  # Par de palavras consecutivas
            if G.has_edge(*word_pair):
                G[word_pair[0]][word_pair[1]]['weight'] += 1  # Fortalecer a conexão existente
            else:
                G.add_edge(*word_pair, weight=1)  # Adicionar nova conexão
    return G

G = build_cooccurrence_graph(df['text'])

# %% [markdown]
# ### Ajusta os dados para Plotar

# %%
# Obter todas as arestas e seus pesos
edges = G.edges(data=True)

# Filtrar para remover arestas entre palavras iguais
filtered_edges = [(u, v, data) for u, v, data in edges if u != v]

# Ordenar as arestas por peso em ordem decrescente
sorted_edges = sorted(filtered_edges, key=lambda x: x[2]['weight'], reverse=True)

# Manter apenas as 100 conexões mais fortes (ou menos se houver menos de 100)
top_edges = sorted_edges[:100]

# Criar um novo grafo com apenas as arestas mais fortes
G_filtered = nx.Graph()
G_filtered.add_edges_from((u, v, data) for u, v, data in top_edges)

# Aplicar normalização e escalonamento logarítmico aos pesos das arestas
edge_weights = np.array([data['weight'] for u, v, data in G_filtered.edges(data=True)])
scaled_edge_weights = np.log1p(edge_weights)

# Definir uma largura máxima para as arestas e limitar as larguras escaladas das arestas
max_edge_width = 3
scaled_edge_weights = np.clip(scaled_edge_weights, 0, max_edge_width)

# Criar um mapeamento das arestas para suas larguras limitadas
edge_widths = { (u, v): w for (u, v), w in zip(G_filtered.edges(), scaled_edge_weights) }

# Layout para visualização
pos = nx.spring_layout(G_filtered, k=1.0)  # Ajuste o valor de k conforme necessário

# Aumentar o tamanho dos nós
node_size = 700  # Ajuste conforme necessário

# %% [markdown]
# ### Desenha o Network Graph

# %%
# Desenhar o grafo
plt.figure(figsize=(14, 12))  # Aumentar o tamanho da figura
nx.draw(G_filtered, pos, with_labels=False, node_color='skyblue', node_size=node_size, font_size=10,
        width=[edge_widths[(u, v)] for u, v in G_filtered.edges()])

# Desenhar rótulos dos nós
labels = {node: node for node in G_filtered.nodes()}  
nx.draw_networkx_labels(G_filtered, pos, labels=labels, font_size=12, font_family='sans-serif', 
                        bbox=dict(facecolor='white', alpha=0.5))

# Desenhar rótulos das arestas
weights = nx.get_edge_attributes(G_filtered, 'weight')
nx.draw_networkx_edge_labels(G_filtered, pos, edge_labels={(u, v): f'{d["weight"]}' for u, v, d in top_edges})

plt.title('Filtered Graph with Top 100 Strongest Connections (No Self-Loops)')
plt.show()
